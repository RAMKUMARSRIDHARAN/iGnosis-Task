# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Dataset

# %%
# Load datasets
purchase = pd.read_csv("purchase_behaviour.csv")
transaction = pd.read_csv("transaction_data.csv")

# %%
purchase
# Out:
#        LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0                1000   YOUNG SINGLES/COUPLES          Premium
# 1                1002   YOUNG SINGLES/COUPLES       Mainstream
# 2                1003          YOUNG FAMILIES           Budget
# 3                1004   OLDER SINGLES/COUPLES       Mainstream
# 4                1005  MIDAGE SINGLES/COUPLES       Mainstream
# ...               ...                     ...              ...
# 72632         2370651  MIDAGE SINGLES/COUPLES       Mainstream
# 72633         2370701          YOUNG FAMILIES       Mainstream
# 72634         2370751          YOUNG FAMILIES          Premium
# 72635         2370961          OLDER FAMILIES           Budget
# 72636         2373711   YOUNG SINGLES/COUPLES       Mainstream
#
# [72637 rows x 3 columns]

# %%
transaction
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43605          1            1343     383        61
# 3       43329          2            2373     974        69
# 4       43330          2            2426    1038       108
# ...       ...        ...             ...     ...       ...
# 264831  43533        272          272319  270088        89
# 264832  43325        272          272358  270154        74
# 264833  43410        272          272379  270187        51
# 264834  43461        272          272379  270188        42
# 264835  43365        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# 1                       CCs Nacho Cheese    175g         3        6.3
# ...

# %%
purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72637 entries, 0 to 72636
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    72637 non-null  int64
#  1   LIFESTAGE         72637 non-null  object
#  2   PREMIUM_CUSTOMER  72637 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  int64
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 16.2+ MB

# %%
purchase.describe()
# Out:
#        LYLTY_CARD_NBR
# count    7.263700e+04
# mean     1.361859e+05
# std      8.989293e+04
# min      1.000000e+03
# 25%      6.620200e+04
# 50%      1.340400e+05
# 75%      2.033750e+05
# max      2.373711e+06

# %%
transaction.describe()
# Out:
#                 DATE     STORE_NBR  LYLTY_CARD_NBR        TXN_ID  \
# count  264836.000000  264836.00000    2.648360e+05  2.648360e+05
# mean    43464.036260     135.08011    1.355495e+05  1.351583e+05
# std       105.389282      76.78418    8.057998e+04  7.813303e+04
# min     43282.000000       1.00000    1.000000e+03  1.000000e+00
# 25%     43373.000000      70.00000    7.002100e+04  6.760150e+04
# 50%     43464.000000     130.00000    1.303575e+05  1.351375e+05
# 75%     43555.000000     203.00000    2.030942e+05  2.027012e+05
# max     43646.000000     272.00000    2.373711e+06  2.415841e+06
#
#             PROD_NBR       PROD_QTY      TOT_SALES
# count  264836.000000  264836.000000  264836.000000
# mean       56.583157       1.907309       7.304200
# std        32.826638       0.643654       3.083226
# min         1.000000       1.000000       1.500000
# 25%        28.000000       2.000000       5.400000
# 50%        56.000000       2.000000       7.400000
# ...

# %% [markdown]
# # Merging the both Dataset and save Dataframe as " Market_Segment"

# %%
# Merge both datasets on LYLTY_CARD_NBR
Market_Segment = transaction.merge(purchase, on="LYLTY_CARD_NBR", how="left")

# %%
Market_Segment
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43605          1            1343     383        61
# 3       43329          2            2373     974        69
# 4       43330          2            2426    1038       108
# ...       ...        ...             ...     ...       ...
# 264831  43533        272          272319  270088        89
# 264832  43325        272          272358  270154        74
# 264833  43410        272          272379  270187        51
# 264834  43461        272          272379  270188        42
# 264835  43365        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# 1                       CCs Nacho Cheese    175g         3        6.3
# ...

# %% [raw]
# Description: We need to merge both datasets on the common column LYLTY_CARD_NBR (customer ID) to combine transaction data with customer demographics.

# %%
Market_Segment.shape
# Out:
# (264836, 10)

# %%
Market_Segment.columns
# Out:
# Index(['DATE', 'STORE_NBR', 'LYLTY_CARD_NBR', 'TXN_ID', 'PROD_NBR',
#        'PROD_NAME', 'PROD_QTY', 'TOT_SALES', 'LIFESTAGE', 'PREMIUM_CUSTOMER'],
#       dtype='object')

# %% [markdown]
# # Identifying and Including only the Unique columns

# %%
# List of columns to exclude
Include_columns = ["PREMIUM_CUSTOMER","LIFESTAGE","PROD_QTY","PROD_NAME"]  

# Iterate through each column except the excluded ones
for column in Market_Segment.columns:
    if column in Include_columns:
        # Get unique values for the column
        Unique_columns = Market_Segment[column].unique()

        print(f"Unique values for column '{column}':")
        print("-" * 100)
        print(Unique_columns.tolist())  # Convert NumPy array to list for better readability
        print("\n")  # Print a new line for better readability
# Out:
# Unique values for column 'PROD_NAME':
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# Checking the null Values in Dataset

# %%
Market_Segment.isnull().sum()
# Out:
# DATE                0
# STORE_NBR           0
# LYLTY_CARD_NBR      0
# TXN_ID              0
# PROD_NBR            0
# PROD_NAME           0
# PROD_QTY            0
# TOT_SALES           0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %% [markdown]
# # Identify most loyal customers (most transactions)

# %%
loyal_customers = Market_Segment.groupby("LYLTY_CARD_NBR").size().nlargest(10).index
loyal_data = Market_Segment[Market_Segment["LYLTY_CARD_NBR"].isin(loyal_customers)]

# %%
loyal_customers
# Out:
# Index([162039, 172032, 13138, 116181, 128178, 230078, 23192, 94185, 104117,
#        105026],
#       dtype='int64', name='LYLTY_CARD_NBR')

# %%
loyal_data
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 32091   43326         23           23192   19866        42
# 32775   43602        230          230078  232430        68
# 34162   43293         23           23192   19864        55
# 34163   43324         23           23192   19865        24
# 34164   43338         23           23192   19867       108
# ...       ...        ...             ...     ...       ...
# 251333  43580        172          172032  172946        74
# 251334  43592        172          172032  172947        49
# 251335  43617        172          172032  172948       106
# 251336  43636        172          172032  172949        33
# 251337  43638        172          172032  172950        51
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 32091    Doritos Corn Chip Mexican Jalapeno 150g         1        3.9
# 32775        Pringles Chicken    Salt Crips 134g         4       14.8
# ...

# %% [raw]
# Description: To determine their characteristics, we:
#
# 1.Group the loyal_data by LIFESTAGE and PREMIUM_CUSTOMER.
# 2. Count the number of transactions for each segment.

# %% [markdown]
# # Analyze characteristics of most loyal customers

# %%
loyal_customer_segments = loyal_data.groupby(["LIFESTAGE", "PREMIUM_CUSTOMER"]).size().reset_index(name="COUNT")
print("Loyal Customer Characteristics:\n", loyal_customer_segments)
# Out:
# Loyal Customer Characteristics:
#                 LIFESTAGE PREMIUM_CUSTOMER  COUNT
# 0         OLDER FAMILIES           Budget     49
# 1         OLDER FAMILIES       Mainstream     35
# 2         YOUNG FAMILIES           Budget     16
# 3         YOUNG FAMILIES       Mainstream     17
# 4         YOUNG FAMILIES          Premium     33
# 5  YOUNG SINGLES/COUPLES       Mainstream     18

# %% [raw]
# Description: We define loyal customers as those who made the most transactions.
#
# 1. Count transactions per customer (LYLTY_CARD_NBR).
# 2. Select the top 10 customers with the highest number of transactions.
# 3. Filter the dataset to include only these customers.

# %%
# Visualization
plt.figure(figsize=(12, 5))
sns.barplot(data=top_products, x="TOT_SALES", y="PROD_NAME", palette="viridis")
plt.title("Top 3 Most Profitable Products")
plt.xlabel("Total Sales")
plt.ylabel("Product Name")
plt.show()

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data=loyal_customer_segments, x="LIFESTAGE", y="COUNT", hue="PREMIUM_CUSTOMER", palette="coolwarm")
plt.title("Loyal Customer Segments")
plt.xticks(rotation=45)
plt.ylabel("Number of Transactions")
plt.show()

# %% [raw]
# Description: We create a barplot to show the distribution of loyal customers across different life stages and premium categories.

# %% [markdown]
# # Identify top 3 most profitable products

# %%
top_products = Market_Segment.groupby("PROD_NAME")["TOT_SALES"].sum().nlargest(3).reset_index()
print("Top 3 Most Profitable Products:\n", top_products)
# Out:
# Top 3 Most Profitable Products:
#                                    PROD_NAME  TOT_SALES
# 0          Dorito Corn Chp     Supreme 380g    40352.0
# 1    Smiths Crnkle Chip  Orgnl Big Bag 380g    36367.6
# 2  Smiths Crinkle Chips Salt & Vinegar 330g    34804.2

# %% [raw]
# Description: To determine the most profitable products, we:
#
# 1. Group the data by product name (PROD_NAME).
# 2. Sum up the total sales (TOT_SALES) for each product.
# 3. Sort the products in descending order of total sales.
# 4. Select the top 3 products.

# %% [markdown]
# # Formulating a Hypothesis

# %%
print("Hypothesis: Loyal customers tend to be in the \"Premium\" or \"Mainstream\" segment and prefer products that are either healthier or have a strong brand presence. This could be due to their financial capability and brand loyalty.")
# Out:
# Hypothesis: Loyal customers tend to be in the "Premium" or "Mainstream" segment and prefer products that are either healthier or have a strong brand presence. This could be due to their financial capability and brand loyalty.
